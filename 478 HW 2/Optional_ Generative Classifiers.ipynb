# %% [markdown]
# # CMSC 478 Hamin Han
# ## Optional: Generative Classifiers
#
# Implement a simple generative classifier with Gaussian class-conditional densities. Fit each of the class-conditional distributions using maximum likelihood and plot the resulting decision boundaries.
#
# Relevant Readings: 3.6.2 from Undergraduate Fundamentals of Machine Learning and 4.2.2 from Bishop

# %% [markdown]
# Oranges, Lemons and Apples dataset
# https://homepages.inf.ed.ac.uk/imurray2/teaching/oranges_and_lemons/
