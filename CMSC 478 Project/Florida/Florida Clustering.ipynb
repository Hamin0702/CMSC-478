# %% [markdown]
# # Clustering - Florida
#
# Using the K-Means clustering algorithm, it will create clusters with the Covid-19 data in Florida counties. </br>
# The main objective with looking at geography is to see if the clustering will show a direct relationship between the number of covid cases and population density in the counties.</br>
# There should be obvious signs in our clusters that the counties that are located near populous cities have drastically more covid cases.</br></br>
#
# Data is taken from: https://covid.cdc.gov/covid-data-tracker/#county-view?list_select_state=Florida&data-type=Cases&metric-cases=Cases_7_day_count_change

# %% [markdown]
# ### Importing all the libraries and data

# %%
# import libraries

import pandas as pd
import numpy as np
import random as rd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn.cluster import KMeans

# %%
# import the data csv file

data = pd.read_csv('county_level_latest_data_for_florida.csv', skiprows=2, on_bad_lines='skip')
data.columns = [x.replace("\n", " ") for x in data.columns.to_list()]
data.head()
# Out:
#    FIPS code State Name           County  Weekly Cases  \
# 0      12001    Florida   Alachua County           161
# 1      12003    Florida     Baker County             7
# 2      12005    Florida       Bay County            93
# 3      12007    Florida  Bradford County            11
# 4      12009    Florida   Brevard County           364
#
#    Weekly Case rate /100k  % Change in weekly Cases from past week  \
# 0                   59.84                                    37.61
# 1                   23.96                                   -12.50
# 2                   53.23                                    55.00
# 3                   39.01                                    83.33
# 4                   60.47                                    47.97
#
#    Test positivity rate - last 7 days  Test positivity rate - absolute change  \
# 0                                9.88                                    0.65
# 1                                6.74                                   -4.58
# 2                                3.33                                   -0.23
# 3                                5.33                                    2.16
# 4                                9.68                                    0.04
#
#    Total diagnostic tests - last 7 days  \
# 0                                  1677
# 1                                   108
# 2                                  1151
# 3                                   278
# 4                                  2957
#
#    Total diagnostic tests per 100k - last 7 days  ...  Percent uninsured - US  \
# 0                                         618.32  ...                     9.2
# 1                                         365.28  ...                     9.2
# 2                                         671.83  ...                     9.2
# 3                                         972.27  ...                     9.2
# 4                                         485.98  ...                     9.2
#
#   Poverty rate - US  Percent population 65+ years - US  \
# 0              10.5                               16.3
# 1              10.5                               16.3
# 2              10.5                               16.3
# 3              10.5                               16.3
# 4              10.5                               16.3
#
#   Total county population  Metropolitan status  NCHS urban/rural class  \
# 0                  269043                Metro            Medium metro
# 1                   29210                Metro      Large fringe metro
# 2                  174705                Metro             Small metro
# 3                   28201            Non-metro                 Noncore
# 4                  601942                Metro            Medium metro
#
#                                     RUCC description  Total state population  \
# 0  Counties in metro areas of 250000 to 1 million...                21477737
# 1  Counties in metro areas of 1 million populatio...                21477737
# 2  Counties in metro areas of fewer than 250000 p...                21477737
# 3  Urban population of 2500 to 19999 adjacent to ...                21477737
# 4  Counties in metro areas of 250000 to 1 million...                21477737
#
#    Total US population  Health Service Area Number
# 0            331996199                         159
# 1            331996199                         158
# 2            331996199                         155
# 3            331996199                         159
# 4            331996199                         237
#
# [5 rows x 52 columns]

# %% [markdown]
# ### Prepping for K-means CLustering

# %%
X = data[['Population density - county','Weekly Cases']]

# %% [markdown]
# ### Elbow Method to Find the Optimal K-value

# %%
cost =[]
for i in range(1, 11):
    KM = KMeans(n_clusters = i, max_iter = 500)
    KM.fit(X)
     
    # calculates squared error
    # for the clustered points
    cost.append(KM.inertia_)    
 
# plot the cost against K values
plt.plot(range(1, 11), cost, color ='g', linewidth ='3')
plt.title('The Elbow Method')
plt.xlabel("Value of K")
plt.ylabel("Squared Error (Cost)")
plt.show() # clear the plot

# %% [markdown]
# ### Implementation of K-means clustering using the Sklearn library

# %%
# Using sklearn library, implement K-means clustering

kmeans = KMeans(3) # From the value taken from the elbow method
kmeans.fit(X)
identified_clusters = kmeans.fit_predict(X)

data_with_clusters = data.copy()
data_with_clusters['Clusters'] = identified_clusters 
plt.scatter(data_with_clusters['Population density - county'],data_with_clusters['Weekly Cases'],c=data_with_clusters['Clusters'],cmap='rainbow')
plt.title('COVID-19 Cases in Florida Counties')
plt.xlabel('Population Density (Persons per Square Mile)')
plt.ylabel('Weekly Cases')
plt.show()

# %% [markdown]
# ### Evaluating the Quality of the Clustering with the Silhouette Score

# %%
score = metrics.silhouette_score(X, kmeans.labels_, metric='euclidean')
print('Average Silhouette Score over All Samples: %.3f' % score)
# Out:
# Average Silhouette Score over All Samples: 0.754
